# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sea
from sklearn.linear_model import LogisticRegression

# %%
data = np.loadtxt('bg1_i_fake_stars_2.csv',delimiter=',')

# %%
in_mags = data[0,:]
out_mags = data[1,:]
recovered = (out_mags - in_mags) < 40

# %%
diff = out_mags - in_mags

# %%
fig,ax = plt.subplots(figsize=(10,5))
ax.scatter(out_mags,diff,s=1.)
ax.set_ylim(-2,2)
ax.set_xlim(20,27)
# Out:
# (20, 27)

# %%
lr = LogisticRegression()

# %%
foo = np.arange(20,27,0.01)

# %%
curve_2 = lr.predict_proba(foo.reshape(foo.shape[0],1))[:,1]

# %%
fig,ax = plt.subplots(figsize=(10,5))
ax.scatter(in_mags,recovered.astype(int),s=0.5)
ax.plot(foo,curve)
ax.plot(foo,curve_2)
ax.set_xlim(20,27)
# Out:
# (20, 27)
